# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the Data to run Panadas

bikes = pd.read_csv('london_merged.csv')

# %%
bikes.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
# Exploration of the data

bikes.dtypes
# Out:
# timestamp        object
# cnt               int64
# t1              float64
# t2              float64
# hum             float64
# wind_speed      float64
# weather_code    float64
# is_holiday      float64
# is_weekend      float64
# season          float64
# dtype: object

# %%
bikes.describe().T
# Out:
#                 count         mean          std   min    25%    50%      75%  \
# cnt           17414.0  1143.101642  1085.108068   0.0  257.0  844.0  1671.75
# t1            17414.0    12.468091     5.571818  -1.5    8.0   12.5    16.00
# t2            17414.0    11.520836     6.615145  -6.0    6.0   12.5    16.00
# hum           17414.0    72.324954    14.313186  20.5   63.0   74.5    83.00
# wind_speed    17414.0    15.913063     7.894570   0.0   10.0   15.0    20.50
# weather_code  17414.0     2.722752     2.341163   1.0    1.0    2.0     3.00
# is_holiday    17414.0     0.022051     0.146854   0.0    0.0    0.0     0.00
# is_weekend    17414.0     0.285403     0.451619   0.0    0.0    0.0     1.00
# season        17414.0     1.492075     1.118911   0.0    0.0    1.0     2.00
#
#                  max
# cnt           7860.0
# t1              34.0
# t2              34.0
# hum            100.0
# wind_speed      56.5
# weather_code    26.0
# is_holiday       1.0
# ...

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
bikes = bikes.dropna()

for cols in bikes.columns:
    percent_missing = np.mean(bikes[cols].isnull())
    print('{} - {}%'.format(cols,percent_missing))
# Out:
# timestamp - 0.0%
# cnt - 0.0%
# t1 - 0.0%
# t2 - 0.0%
# hum - 0.0%
# wind_speed - 0.0%
# weather_code - 0.0%
# is_holiday - 0.0%
# is_weekend - 0.0%
# season - 0.0%

# %%
bikes.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
# Want to see the unique values of weather code in data

bikes.weather_code.value_counts()
# Out:
# weather_code
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: count, dtype: int64

# %%
# Repeated for the season

bikes.season.value_counts()
# Out:
# season
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: count, dtype: int64

# %%
# Renaming column names to my liking

new_cols_dict = {
    'timestamp':'time',
    'cnt':'count',
    't1':'temp_real_C',
    't2':'temp_feels_like_C',
    'hum':'humidity_percent',
    'wind_speed':'wind_speed_kph',
    'weather_code':'weather',
    'is_holiday':'is_holiday',
    'is_weekend':'is_weekend',  
    'season':'season'}

bikes.rename(new_cols_dict, axis=1, inplace=True)

# %%
bikes.head()
# Out:
#                   time  count  temp_real_C  temp_feels_like_C  \
# 0  2015-01-04 00:00:00    182          3.0                2.0
# 1  2015-01-04 01:00:00    138          3.0                2.5
# 2  2015-01-04 02:00:00    134          2.5                2.5
# 3  2015-01-04 03:00:00     72          2.0                2.0
# 4  2015-01-04 04:00:00     47          2.0                0.0
#
#    humidity_percent  wind_speed_kph  weather  is_holiday  is_weekend  season
# 0              93.0             6.0      3.0         0.0         1.0     3.0
# 1              93.0             5.0      1.0         0.0         1.0     3.0
# 2              96.5             0.0      1.0         0.0         1.0     3.0
# 3             100.0             0.0      1.0         0.0         1.0     3.0
# 4              93.0             6.5      1.0         0.0         1.0     3.0

# %%
# Changing the humidity values ot percentage 
bikes.humidity_percent = bikes.humidity_percent /100

# %%
# Creating a season dictonary so that we can use the actual written values 

season_dict = {'0.0':'spring',
              '1.0':'summer',
              '2.0':'fall',
              '3.0':'winter'}

# Will repeating the same process for the weather vaules

weather_dict = {'1.0':'Clear',
               '2.0':'Scattered clouds',
               '3.0':'Broken clouds',
               '4.0':'Cloudy',
               '7.0':'Rain',
               '10.0':'Rain with thunderstrom',
               '26.0':'Snowfall'}

# Changing the seasons column data type to string
bikes.season = bikes.season.astype('str')
# Mapping the values 0-3 tot he acutal written seasons
bikes.season = bikes.season.map(season_dict)

#Changing the weather column data type to string as well
bikes.weather = bikes.weather.astype('str')
# Mapping the values to the actual text from of weather
bikes.weather = bikes.weather.map(weather_dict)

# %%
bikes.head()
# Out:
#                   time  count  temp_real_C  temp_feels_like_C  \
# 0  2015-01-04 00:00:00    182          3.0                2.0
# 1  2015-01-04 01:00:00    138          3.0                2.5
# 2  2015-01-04 02:00:00    134          2.5                2.5
# 3  2015-01-04 03:00:00     72          2.0                2.0
# 4  2015-01-04 04:00:00     47          2.0                0.0
#
#    humidity_percent  wind_speed_kph        weather  is_holiday  is_weekend  \
# 0             0.930             6.0  Broken clouds         0.0         1.0
# 1             0.930             5.0          Clear         0.0         1.0
# 2             0.965             0.0          Clear         0.0         1.0
# 3             1.000             0.0          Clear         0.0         1.0
# 4             0.930             6.5          Clear         0.0         1.0
#
#    season
# 0  winter
# 1  winter
# 2  winter
# 3  winter
# 4  winter

# %%
# Saving to an excel file to visualize the datat in Tableau. File name is 'london_bikes_final.xlsx'
bikes.to_excel('london_bikes_final.xlsx', sheet_name='Data')
